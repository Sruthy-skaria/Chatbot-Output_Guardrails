# %% [markdown]
# <a href="https://colab.research.google.com/github/Sruthy-skaria/Chatbot-Output_Guardrails/blob/main/Guardrail_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/Colab\ Notebooks/ChatbotGuardRails
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/ChatbotGuardRails

# %%
# !pip install -r requirements.txt

from dotenv import load_dotenv
load_dotenv()  # This will look for a .env file in your current directory and load its variables.
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.28.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from openai==0.28->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai==0.28->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from openai==0.28->-r requirements.txt (line 1)) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.20.0)
# True

# %%
from guardrail_executer import run_guardrail


question = "What are the key benefits of using a credit card?"
answer = "Credit cards offer rewards, cashback, and travel benefits."
context = "Credit cards provide revolving credit, allowing customers to borrow funds up to a pre-approved limit."

result = await run_guardrail(question, answer, context)
print("Evaluation Result:", result)
# Out:
# 2025-04-30 05:10:34,019 INFO: Received combined guardrail response.
# INFO:guardrails:Received combined guardrail response.
# Evaluation Result: Failed groundedness
